# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-Miri/pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
# !git clone https://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@github.com/Mahdi-Miri/pandas.git
# Out:
# Cloning into 'pandas'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 28 (delta 7), reused 10 (delta 2), pack-reused 0
# Receiving objects: 100% (28/28), 346.47 KiB | 1.90 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/pandas/airlines.csv")

# %%
data.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
data.columns
# Out:
# Index(['Airport.Code', 'Airport.Name', 'Time.Label', 'Time.Month',
#        'Time.Month Name', 'Time.Year', 'Statistics.# of Delays.Carrier',
#        'Statistics.# of Delays.Late Aircraft',
#        'Statistics.# of Delays.National Aviation System',
#        'Statistics.# of Delays.Security', 'Statistics.# of Delays.Weather',
#        'Statistics.Carriers.Names', 'Statistics.Carriers.Total',
#        'Statistics.Flights.Cancelled', 'Statistics.Flights.Delayed',
#        'Statistics.Flights.Diverted', 'Statistics.Flights.On Time',
#        'Statistics.Flights.Total', 'Statistics.Minutes Delayed.Carrier',
#        'Statistics.Minutes Delayed.Late Aircraft',
#        'Statistics.Minutes Delayed.National Aviation System',
#        'Statistics.Minutes Delayed.Security',
#        'Statistics.Minutes Delayed.Total',
#        'Statistics.Minutes Delayed.Weather'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Airport.Code                                         4408 non-null   object
#  1   Airport.Name                                         4408 non-null   object
#  2   Time.Label                                           4408 non-null   object
#  3   Time.Month                                           4408 non-null   int64
#  4   Time.Month Name                                      4408 non-null   object
#  5   Time.Year                                            4408 non-null   int64
#  6   Statistics.# of Delays.Carrier                       4408 non-null   int64
#  7   Statistics.# of Delays.Late Aircraft                 4408 non-null   int64
# ...

# %%
data['Airport.Code']
# Out:
# 0       ATL
# 1       BOS
# 2       BWI
# 3       CLT
# 4       DCA
#        ...
# 4403    SAN
# 4404    SEA
# 4405    SFO
# 4406    SLC
# 4407    TPA
# Name: Airport.Code, Length: 4408, dtype: object

# %%
df0 = data[['Airport.Code','Airport.Name']]

# %%
df0
# Out:
#      Airport.Code                                       Airport.Name
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
# [4408 rows x 2 columns]

# %%
data.tail()
# Out:
#      Airport.Code                                      Airport.Name  \
# 4403          SAN            San Diego, CA: San Diego International
# 4404          SEA         Seattle, WA: Seattle/Tacoma International
# 4405          SFO    San Francisco, CA: San Francisco International
# 4406          SLC  Salt Lake City, UT: Salt Lake City International
# 4407          TPA                    Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 4403    2016/01           1         January       2016
# 4404    2016/01           1         January       2016
# 4405    2016/01           1         January       2016
# 4406    2016/01           1         January       2016
# 4407    2016/01           1         January       2016
#
#       Statistics.# of Delays.Carrier  Statistics.# of Delays.Late Aircraft  \
# 4403                             280                                   397
# ...

# %%
data.head(1)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
#
#    Statistics.# of Delays.Late Aircraft  \
# 0                                  1275
#
#    Statistics.# of Delays.National Aviation System  \
# 0                                             3217
#
#    Statistics.# of Delays.Security  ...  Statistics.Flights.Delayed  \
# 0                               17  ...                        5843
#
#   Statistics.Flights.Diverted  Statistics.Flights.On Time  \
# 0                          27                       23974
#
#    Statistics.Flights.Total  Statistics.Minutes Delayed.Carrier  \
# 0                     30060                               61606
#
#    Statistics.Minutes Delayed.Late Aircraft  \
# ...

# %%
data.iloc[0]
# Out:
# Airport.Code                                                                                         ATL
# Airport.Name                                           Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# Time.Label                                                                                       2003/06
# Time.Month                                                                                             6
# Time.Month Name                                                                                     June
# Time.Year                                                                                           2003
# Statistics.# of Delays.Carrier                                                                      1009
# Statistics.# of Delays.Late Aircraft                                                                1275
# Statistics.# of Delays.National Aviation System                                                     3217
# ...

# %%
data.rank()
# Out:
#       Airport.Code  Airport.Name  Time.Label  Time.Month  Time.Month Name  \
# 0             76.5          76.5        15.0      1958.0           2393.0
# 1            228.5         380.5        15.0      1958.0           2393.0
# 2            380.5         228.5        15.0      1958.0           2393.0
# 3            532.5         532.5        15.0      1958.0           2393.0
# 4            684.5        4180.5        15.0      1958.0           2393.0
# ...            ...           ...         ...         ...              ...
# 4403        3724.5        3572.5      4394.0       189.0           1639.0
# 4404        3876.5        3876.5      4394.0       189.0           1639.0
# 4405        4028.5        3724.5      4394.0       189.0           1639.0
# 4406        4180.5        3420.5      4394.0       189.0           1639.0
# 4407        4332.5        4028.5      4394.0       189.0           1639.0
#
#       Time.Year  Statistics.# of Delays.Carrier  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Airport.Code                                         4408 non-null   object
#  1   Airport.Name                                         4408 non-null   object
#  2   Time.Label                                           4408 non-null   object
#  3   Time.Month                                           4408 non-null   int64
#  4   Time.Month Name                                      4408 non-null   object
#  5   Time.Year                                            4408 non-null   int64
#  6   Statistics.# of Delays.Carrier                       4408 non-null   int64
#  7   Statistics.# of Delays.Late Aircraft                 4408 non-null   int64
# ...

# %%
data.describe()
# Out:
#         Time.Month    Time.Year  Statistics.# of Delays.Carrier  \
# count  4408.000000  4408.000000                     4408.000000
# mean      6.578947  2009.243421                      574.632486
# std       3.457890     3.667475                      329.616475
# min       1.000000  2003.000000                      112.000000
# 25%       4.000000  2006.000000                      358.000000
# 50%       7.000000  2009.000000                      476.000000
# 75%      10.000000  2012.000000                      692.000000
# max      12.000000  2016.000000                     3087.000000
#
#        Statistics.# of Delays.Late Aircraft  \
# count                           4408.000000
# mean                             789.078947
# std                              561.798420
# min                               86.000000
# 25%                              425.000000
# 50%                              618.500000
# 75%                              959.000000
# ...

# %%
data
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 0       2003/06           6            June       2003
# ...

# %%
    data.shape
# Out:
# (4408, 24)

# %%
data.size
# Out:
# 105792

# %%
data.sample(5)
# Out:
#      Airport.Code                                  Airport.Name Time.Label  \
# 1240          PHL  Philadelphia, PA: Philadelphia International    2006/12
# 3452          BOS               Boston, MA: Logan International    2013/05
# 389           JFK   New York, NY: John F. Kennedy International    2004/07
# 2022          PDX          Portland, OR: Portland International    2009/03
# 131           LGA                       New York, NY: LaGuardia    2003/10
#
#       Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 1240          12        December       2006                             528
# 3452           5             May       2013                             510
# 389            7            July       2004                             548
# 2022           3           March       2009                             251
# 131           10         October       2003                             281
#
#       Statistics.# of Delays.Late Aircraft  \
# ...

# %%
 import matplotlib.pyplot as plt

# %%
df1 = data['Airport.Name']
df2 = data['Airport.Code']

# %%
plt.bar(df1,df2)
plt.ylabel('Airport.Code')
plt.xlabel('Airport.Name')
plt.show()

# %%
df3 = data.sample(50)

# %%
df1 = df3['Airport.Name']
df2 = df3['Airport.Code']
plt.bar(df1,df2)
plt.ylabel('Airport.Code')
plt.xlabel('Airport.Name')
plt.show()

# %%
data.dtypes
# Out:
# Airport.Code                                           object
# Airport.Name                                           object
# Time.Label                                             object
# Time.Month                                              int64
# Time.Month Name                                        object
# Time.Year                                               int64
# Statistics.# of Delays.Carrier                          int64
# Statistics.# of Delays.Late Aircraft                    int64
# Statistics.# of Delays.National Aviation System         int64
# Statistics.# of Delays.Security                         int64
# Statistics.# of Delays.Weather                          int64
# Statistics.Carriers.Names                              object
# Statistics.Carriers.Total                               int64
# Statistics.Flights.Cancelled                            int64
# Statistics.Flights.Delayed                              int64
# ...

# %%
data.describe()
# Out:
#         Time.Month    Time.Year  Statistics.# of Delays.Carrier  \
# count  4408.000000  4408.000000                     4408.000000
# mean      6.578947  2009.243421                      574.632486
# std       3.457890     3.667475                      329.616475
# min       1.000000  2003.000000                      112.000000
# 25%       4.000000  2006.000000                      358.000000
# 50%       7.000000  2009.000000                      476.000000
# 75%      10.000000  2012.000000                      692.000000
# max      12.000000  2016.000000                     3087.000000
#
#        Statistics.# of Delays.Late Aircraft  \
# count                           4408.000000
# mean                             789.078947
# std                              561.798420
# min                               86.000000
# 25%                              425.000000
# 50%                              618.500000
# 75%                              959.000000
# ...

# %%
data['Airport.Name'].describe()
# Out:
# count                                                  4408
# unique                                                   29
# top       Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# freq                                                    152
# Name: Airport.Name, dtype: object

# %%
data['Time.Month'].describe()
# Out:
# count    4408.000000
# mean        6.578947
# std         3.457890
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%        10.000000
# max        12.000000
# Name: Time.Month, dtype: float64

# %%
data['Time.Month'].mean()
# Out:
# 6.578947368421052

# %%
df4 = data.sample(400)

# %%
# !pip install beautifulsoup4

# %%
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://en.wikipedia.org/wiki/List_of_programming_languages_by_type")

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>List of programming languages by type - Wikipedia</title>
# ...

# %%
soup = BeautifulSoup(response.text , 'html.parser')

# %%
print(soup.body)
# Out:
# <body class="skin--responsive skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_programming_languages_by_type rootpage-List_of_programming_languages_by_type skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Site" class="vector-main-menu-landmark">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# ...

# %%
print(soup.title)
# Out:
# <title>List of programming languages by type - Wikipedia</title>

# %%
print(soup.find_all('table'))
# Out:
# [<table class="sidebar nomobile nowraplinks" style="width:18.0em;"><tbody><tr><th class="sidebar-title" style="background:#ddddff; font-size:110%;"><a href="/wiki/Lists_of_programming_languages" title="Lists of programming languages">Programming language<br/>lists</a></th></tr><tr><td class="sidebar-content" style="text-align: left;">
# <ul><li><a href="/wiki/List_of_programming_languages" title="List of programming languages">Alphabetical</a></li>
# <li><a class="mw-selflink selflink">Categorical</a></li>
# <li><a href="/wiki/Timeline_of_programming_languages" title="Timeline of programming languages">Chronological</a></li>
# <li><a href="/wiki/Generational_list_of_programming_languages" title="Generational list of programming languages">Generational</a></li></ul></td>
# ...

# %%
 print(soup.find_all('p'))
# Out:
# [<p class="mw-empty-elt">
# </p>, <p>This is a list of notable <a href="/wiki/Programming_language" title="Programming language">programming languages</a>, grouped by type.
# </p>, <p>The groupings are overlapping; not mutually exclusive. A language can be listed in multiple groupings.
# </p>, <p>Agent-oriented programming allows the developer to build, extend and use <a href="/wiki/Software_agent" title="Software agent">software agents</a>, which are abstractions of objects that can message other agents.
# ...

# %%
print(soup.find_all('class'))
# Out:
# []

# %%
print(soup.select('.Examples'))
# Out:
# []

# %%
# !pip install lxml

# %%
data1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_programming_languages_by_type")

# %%
data1
# Out:
# [                          Programming language lists
#  0  Alphabetical Categorical Chronological Generat...
#  1                                                vte,
#      0                                                  1
#  0 NaN  This section needs expansion. You can help by ...,
#      0                                                  1
#  0 NaN  This section needs expansion. You can help by ...,
#      0                                                  1
#  0 NaN  This section needs expansion. You can help by ...,
#             Language                    Originator First appeared  \
#  0             ESPOL         Burroughs Corporation           1961
#  1              PL/I                    IBM, SHARE           1964
#  2             PL360                 Niklaus Wirth           1968
#  3                 C                Dennis Ritchie           1969
#  4              PL/S                           IBM           196x
# ...

# %%
df5 = data1[4]

# %%
df5
# Out:
#            Language                    Originator First appeared  \
# 0             ESPOL         Burroughs Corporation           1961
# 1              PL/I                    IBM, SHARE           1964
# 2             PL360                 Niklaus Wirth           1968
# 3                 C                Dennis Ritchie           1969
# 4              PL/S                           IBM           196x
# 5             BLISS    Carnegie Mellon University           1970
# 6              PL/8                           IBM           197x
# 7   PL/MP and PL/MI                           IBM           197x
# 8              PL-6               Honeywell, Inc.           197x
# 9             SYMPL                           CDC           197x
# 10              C++             Bjarne Stroustrup           1979
# 11              Ada  Jean Ichbiah, S. Tucker Taft           1983
# 12                D                  Digital Mars           2001
# ...

# %%
df5['Originator']
# Out:
# 0            Burroughs Corporation
# 1                       IBM, SHARE
# 2                    Niklaus Wirth
# 3                   Dennis Ritchie
# 4                              IBM
# 5       Carnegie Mellon University
# 6                              IBM
# 7                              IBM
# 8                  Honeywell, Inc.
# 9                              CDC
# 10               Bjarne Stroustrup
# 11    Jean Ichbiah, S. Tucker Taft
# 12                    Digital Mars
# 13                   Andreas Rumpf
# 14            Mozilla Research[36]
# 15                      Apple Inc.
# 16                   Andrew Kelley
# 17           Alexander Medvednikov
# Name: Originator, dtype: object

# %%
df5.dtypes
# Out:
# Language          object
# Originator        object
# First appeared    object
# Influenced by     object
# Used for          object
# dtype: object
